# %% [markdown]
# # Ocean TEMP views

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import xarray as xr

import catalog
import util

xr.set_options(keep_attrs=True)
# Out:
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/dask_jobqueue/core.py:20: FutureWarning: tmpfile is deprecated and will be removed in a future release. Please use dask.utils.tmpfile instead.
#   from distributed.utils import tmpfile

# %%
case = 'smyle-fosi.regional.lat-range-basin.000'
component = 'pop'
stream = 'h'

variable_id = 'TEMP'

n_workers = 32

# %%
# Parameters
variable_id = "TEMP"
n_workers = 32

# %%
assert component in ['pop']
assert stream in ['h', 'h.ecosys.nday1']

# %%
cluster, client = util.get_ClusterClient()
cluster.scale(n_workers)
client
# Out:
# /glade/work/mclong/miniconda3/envs/onets/lib/python3.7/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 34887 instead
#   f"Port {expected} is already in use.\n"
# <Client: 'tcp://10.12.206.63:34646' processes=0 threads=0, memory=0 B>

# %%
dsets = catalog.to_dataset_dict(
    case=case,
    component=component,
    stream=stream,
)
dsets.keys()
# Out:
# dict_keys(['smyle-fosi.regional.lat-range-basin.000.pop.h'])

# %%
ds = dsets[f'{case}.{component}.{stream}']

# %%
dt_wgt = ds.time_bound.diff('d2').squeeze()
dt_wgt /= dt_wgt.sum()
dt_wgt
# Out:
# <xarray.DataArray 'time_bound' (time: 12)>
# dask.array<truediv, shape=(12,), dtype=float64, chunksize=(1,), chunktype=numpy.ndarray>
# Coordinates:
#   * time     (time) object 0347-01-16 12:00:00 ... 0347-12-16 12:00:00
# Attributes:
#     long_name:  boundaries for time-averaging interval
#     units:      days since 0000-01-01 00:00:00

# %%
ds[variable_id].weighted(dt_wgt).mean('time').isel(z_t=0).plot()
